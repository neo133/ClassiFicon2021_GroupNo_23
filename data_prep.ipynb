# %% [markdown]
# <b> First extract the given happy_images.zip. Then run the below code </b>

# %%
import pandas as pd
import numpy as np
import os
import shutil

dir1="task1"
if os.path.exists(dir1):
                shutil.rmtree(dir1)
os.makedirs(dir1)
dir1="task2"
if os.path.exists(dir1):
                shutil.rmtree(dir1)
os.makedirs(dir1)

df = pd.read_csv('train.csv',names=["image", "class"])
classes=df['class'].unique()
dir1="task1/train"
if os.path.exists(dir1):
                shutil.rmtree(dir1)
os.makedirs(dir1)
dir2="task1/train/positive smile"
if os.path.exists(dir2):
                        shutil.rmtree(dir2)
os.makedirs(dir2)
dir3="task1/train/NOT smile"
if os.path.exists(dir3):
                    shutil.rmtree(dir3)
os.makedirs(dir3)
     
dir4="task2/train"
if os.path.exists(dir4):
                shutil.rmtree(dir4)
os.makedirs(dir4)

dir5="task2/train/positive smile"
if os.path.exists(dir5):
                        shutil.rmtree(dir5)
os.makedirs(dir5)
dir6="task2/train/negative smile"
if os.path.exists(dir6):
                    shutil.rmtree(dir6)
os.makedirs(dir6)
data_dir="happy_images/"



df1=df[(df == classes[1]).any(axis=1)].values
for img in df1:
    shutil.copy(data_dir+img[0]+".jpg", dir2)

df1=df[(df == classes[2]).any(axis=1)].values
for img in df1:
    shutil.copy(data_dir+img[0]+".jpg", dir3)

df1=df[(df == classes[1]).any(axis=1)].values
for img in df1:
    shutil.copy(data_dir+img[0]+".jpg", dir5)

df1=df[(df == classes[0]).any(axis=1)].values
for img in df1:
    shutil.copy(data_dir+img[0]+".jpg", dir6)

df = pd.read_csv('test.csv',names=["image", "class"])
classes=df['class'].unique()
dir1="task1/test"
if os.path.exists(dir1):
                shutil.rmtree(dir1)
os.makedirs(dir1)
dir2="task1/test/positive smile"
if os.path.exists(dir2):
                        shutil.rmtree(dir2)
os.makedirs(dir2)
dir3="task1/test/NOT smile"
if os.path.exists(dir3):
                    shutil.rmtree(dir3)
os.makedirs(dir3)
     
dir4="task2/test"
if os.path.exists(dir4):
                shutil.rmtree(dir4)
os.makedirs(dir4)

dir5="task2/test/positive smile"
if os.path.exists(dir5):
                        shutil.rmtree(dir5)
os.makedirs(dir5)
dir6="task2/test/negative smile"
if os.path.exists(dir6):
                    shutil.rmtree(dir6)
os.makedirs(dir6)
data_dir="happy_images/"

df1=df[(df == classes[1]).any(axis=1)].values
for img in df1:
    shutil.copy(data_dir+img[0]+".jpg", dir2)

df1=df[(df == classes[2]).any(axis=1)].values
for img in df1:
    shutil.copy(data_dir+img[0]+".jpg", dir3)

df1=df[(df == classes[1]).any(axis=1)].values
for img in df1:
    shutil.copy(data_dir+img[0]+".jpg", dir5)

df1=df[(df == classes[0]).any(axis=1)].values
for img in df1:
    shutil.copy(data_dir+img[0]+".jpg", dir6)
